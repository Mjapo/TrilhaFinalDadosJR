# %%
import pandas as pd

# Lendo o arquivo CSV
FeedBack = pd.read_csv('../Data/feedback_julho2024.csv', encoding='latin1')

# %%
FeedBack.head(5)
# Out:
#          data               nome_completo atualmente_sou  \
# 0  2024-07-24  Fernando Silva de Oliveira         membro
# 1  2024-07-25   Gabriela Costa de Almeida         membro
# 2  2024-07-26   Hugo Fernandes dos Santos         membro
# 3  2024-07-27   Isabela Oliveira da Silva         membro
# 4  2024-07-28      JoÃ£o Costa de Almeida         membro
#
#                     minha_equipe reunioes_do_time colaboracao_entre_membros  \
# 0   equipe_de_desenvolvimento_04       satisfeito                satisfeito
# 1   equipe_de_desenvolvimento_06       satisfeito                satisfeito
# 2   equipe_de_desenvolvimento_06       satisfeito                satisfeito
# 3   equipe_de_desenvolvimento_04           neutro                satisfeito
# 4   equipe_de_desenvolvimento_05       satisfeito                satisfeito
#
#   ambiente_de_aprendizagem comunicacao_entre_membros  \
# 0               satisfeito                satisfeito
# 1               satisfeito                satisfeito
# 2               satisfeito                satisfeito
# 3               satisfeito                satisfeito
# 4               satisfeito                satisfeito
#
#   satisfacao_geral_comunidade    feedbacks  horas_semanais_dedicadas  \
# 0                  satisfeito   satisfeito                         5
# 1                  satisfeito   satisfeito                        12
# 2                  satisfeito   satisfeito                         6
# 3                  satisfeito   satisfeito                         3
# 4                  satisfeito   satisfeito                        19
#
#                                 comentario_adicional
# 0   O projeto estÃ¡ bem estruturado e a equipe Ã©...
# 1   Primeira vez que faÃ§o parte de um projeto as...
# 2
# 3   Tenho desenvolvido meus conhecimentos de UX/U...
# 4   Tem sido muito empolgante trabalhar com outra...

# %% [markdown]
# ###*** Tamanho da Bases de Dados ***

# %%
FeedBack.shape
# Out:
# (112, 12)

# %%
FeedBack.dtypes
# Out:
# data                           object
# nome_completo                  object
# atualmente_sou                 object
# minha_equipe                   object
# reunioes_do_time               object
# colaboracao_entre_membros      object
# ambiente_de_aprendizagem       object
# comunicacao_entre_membros      object
# satisfacao_geral_comunidade    object
# feedbacks                      object
# horas_semanais_dedicadas        int64
# comentario_adicional           object
# dtype: object

# %%
FeedBack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   data                         112 non-null    object
#  1   nome_completo                112 non-null    object
#  2   atualmente_sou               112 non-null    object
#  3   minha_equipe                 112 non-null    object
#  4   reunioes_do_time             112 non-null    object
#  5   colaboracao_entre_membros    112 non-null    object
#  6   ambiente_de_aprendizagem     112 non-null    object
#  7   comunicacao_entre_membros    112 non-null    object
#  8   satisfacao_geral_comunidade  112 non-null    object
#  9   feedbacks                    112 non-null    object
#  10  horas_semanais_dedicadas     112 non-null    int64
#  11  comentario_adicional         112 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 10.6+ KB

# %%
#visualizando os dados 
FeedBack
# Out:
#            data               nome_completo atualmente_sou  \
# 0    2024-07-24  Fernando Silva de Oliveira         membro
# 1    2024-07-25   Gabriela Costa de Almeida         membro
# 2    2024-07-26   Hugo Fernandes dos Santos         membro
# 3    2024-07-27   Isabela Oliveira da Silva         membro
# 4    2024-07-28      JoÃ£o Costa de Almeida         membro
# ..          ...                         ...            ...
# 107  2024-07-20              Felipe Andrade         membro
# 108  2024-07-12            Bruno Nascimento         membro
# 109  2024-07-13              Camila Freitas         membro
# 110  2024-07-14               Danilo Santos         membro
# 111  2024-07-15               Eliane Mendes         membro
#
#                       minha_equipe reunioes_do_time colaboracao_entre_membros  \
# 0     equipe_de_desenvolvimento_04       satisfeito                satisfeito
# 1     equipe_de_desenvolvimento_06       satisfeito                satisfeito
# 2     equipe_de_desenvolvimento_06       satisfeito                satisfeito
# 3     equipe_de_desenvolvimento_04           neutro                satisfeito
# 4     equipe_de_desenvolvimento_05       satisfeito                satisfeito
# ..                             ...              ...                       ...
# 107   equipe_de_desenvolvimento_07       satisfeito                satisfeito
# 108   equipe_de_desenvolvimento_02       satisfeito                satisfeito
# 109   equipe_de_desenvolvimento_03       satisfeito                    neutro
# 110   equipe_de_desenvolvimento_07       satisfeito                satisfeito
# 111   equipe_de_desenvolvimento_05       satisfeito                satisfeito
#
#     ambiente_de_aprendizagem comunicacao_entre_membros  \
# 0                 satisfeito                satisfeito
# 1                 satisfeito                satisfeito
# 2                 satisfeito                satisfeito
# 3                 satisfeito                satisfeito
# 4                 satisfeito                satisfeito
# ..                       ...                       ...
# 107                   neutro                satisfeito
# 108               satisfeito                satisfeito
# 109               satisfeito                satisfeito
# 110               satisfeito                    neutro
# 111               satisfeito                satisfeito
#
#     satisfacao_geral_comunidade    feedbacks  horas_semanais_dedicadas  \
# 0                    satisfeito   satisfeito                         5
# 1                    satisfeito   satisfeito                        12
# 2                    satisfeito   satisfeito                         6
# 3                    satisfeito   satisfeito                         3
# 4                    satisfeito   satisfeito                        19
# ..                          ...          ...                       ...
# 107                  satisfeito   satisfeito                         5
# 108                  satisfeito   satisfeito                         6
# 109                  satisfeito   satisfeito                         7
# 110                  satisfeito   satisfeito                         8
# 111                  satisfeito   satisfeito                         6
#
#                                   comentario_adicional
# 0     O projeto estÃ¡ bem estruturado e a equipe Ã©...
# 1     Primeira vez que faÃ§o parte de um projeto as...
# 2
# 3     Tenho desenvolvido meus conhecimentos de UX/U...
# 4     Tem sido muito empolgante trabalhar com outra...
# ..                                                 ...
# 107   Ã uma boa oportunidade mas a carga de trabal...
# 108
# 109
# 110
# 111   O projeto Ã© desafiador mas estou gostando de...
#
# [112 rows x 12 columns]

# %% [markdown]
# ### *** Verificando a presenca de dados Ausentes***

# %%
FeedBack.isnull().sum()
# Out:
# data                           0
# nome_completo                  0
# atualmente_sou                 0
# minha_equipe                   0
# reunioes_do_time               0
# colaboracao_entre_membros      0
# ambiente_de_aprendizagem       0
# comunicacao_entre_membros      0
# satisfacao_geral_comunidade    0
# feedbacks                      0
# horas_semanais_dedicadas       0
# comentario_adicional           0
# dtype: int64

# %%
# verificando dados duplicados 
duplicados = FeedBack.duplicated()
print("Linhas duplicadas:")
FeedBack[duplicados]
# Out:
# Linhas duplicadas:
# Empty DataFrame
# Columns: [data, nome_completo, atualmente_sou, minha_equipe, reunioes_do_time, colaboracao_entre_membros, ambiente_de_aprendizagem, comunicacao_entre_membros, satisfacao_geral_comunidade, feedbacks, horas_semanais_dedicadas, comentario_adicional]
# Index: []

# %% [markdown]
# ## ***Explorando os dados***

# %%
FeedBack.describe()
# Out:
#        horas_semanais_dedicadas
# count                112.000000
# mean                   9.321429
# std                    6.049666
# min                    1.000000
# 25%                    5.000000
# 50%                    7.000000
# 75%                   12.000000
# max                   28.000000

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\marce\anaconda3\lib\site-packages (4.24.0)
# Requirement already satisfied: filelock in c:\users\marce\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in c:\users\marce\anaconda3\lib\site-packages (from transformers) (0.10.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\marce\anaconda3\lib\site-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\marce\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\marce\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\marce\anaconda3\lib\site-packages (from transformers) (2022.3.15)
# Requirement already satisfied: requests in c:\users\marce\anaconda3\lib\site-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\marce\anaconda3\lib\site-packages (from transformers) (0.11.4)
# Requirement already satisfied: tqdm>=4.27 in c:\users\marce\anaconda3\lib\site-packages (from transformers) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\marce\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\marce\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: colorama in c:\users\marce\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\marce\anaconda3\lib\site-packages (from requests->transformers) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marce\anaconda3\lib\site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\marce\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marce\anaconda3\lib\site-packages (from requests->transformers) (3.3)
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import pipeline

# Análise de Sentimentos
sentiment_pipeline = pipeline('sentiment-analysis')
Feedback['sentimentos'] = Feedback['comentario_adicional'].dropna().apply(lambda x: sentiment_pipeline(x)[0]['label'])

# Visualização dos Sentimentos
sns.countplot(x='sentimentos', data=df)
plt.title('Distribuição dos Sentimentos nos Comentários Adicionais')
plt.xlabel('Sentimentos')
plt.ylabel('Contagem')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 from transformers import pipeline
#       3 # Análise de Sentimentos
#       4 sentiment_pipeline = pipeline('sentiment-analysis')
#
# File ~\anaconda3\lib\site-packages\transformers\__init__.py:30, in <module>
#      27 from typing import TYPE_CHECKING
#      29 # Check the dependencies satisfy the minimal versions required.
# ---> 30 from . import dependency_versions_check
#      31 from .utils import (
#      32     OptionalDependencyNotAvailable,
#      33     _LazyModule,
#    (...)
#      44     logging,
#      45 )
#      48 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File ~\anaconda3\lib\site-packages\transformers\dependency_versions_check.py:17, in <module>
#      14 import sys
#      16 from .dependency_versions_table import deps
# ---> 17 from .utils.versions import require_version, require_version_core
#      20 # define which module versions we always want to check at run time
#      21 # (usually the ones defined in `install_requires` in setup.py)
#      22 #
#      23 # order specific notes:
#      24 # - tqdm must be checked before tokenizers
#      26 pkgs_to_check_at_runtime = "python tqdm regex requests packaging filelock numpy tokenizers".split()
#
# File ~\anaconda3\lib\site-packages\transformers\utils\__init__.py:34, in <module>
#      25 from .constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, IMAGENET_STANDARD_MEAN, IMAGENET_STANDARD_STD
#      26 from .doc import (
#      27     add_code_sample_docstrings,
#      28     add_end_docstrings,
#    (...)
#      32     replace_return_docstrings,
#      33 )
# ---> 34 from .generic import (
#      35     ContextManagers,
#      36     ExplicitEnum,
#      37     ModelOutput,
#      38     PaddingStrategy,
#      39     TensorType,
#      40     cached_property,
#      41     expand_dims,
#      42     find_labels,
#      43     flatten_dict,
#      44     is_jax_tensor,
#      45     is_numpy_array,
#      46     is_tensor,
#      47     is_tf_tensor,
#      48     is_torch_device,
#      49     is_torch_tensor,
#      50     reshape,
#      51     squeeze,
#      52     tensor_size,
#      53     to_numpy,
#      54     to_py_obj,
#      55     transpose,
#      56     working_or_temp_dir,
#      57 )
#      58 from .hub import (
#      59     CLOUDFRONT_DISTRIB_PREFIX,
#      60     DISABLE_TELEMETRY,
#    (...)
#      86     send_example_telemetry,
#      87 )
#      88 from .import_utils import (
#      89     ENV_VARS_TRUE_AND_AUTO_VALUES,
#      90     ENV_VARS_TRUE_VALUES,
#    (...)
#     163     torch_version,
#     164 )
#
# File ~\anaconda3\lib\site-packages\transformers\utils\generic.py:33, in <module>
#      29 from .import_utils import is_flax_available, is_tf_available, is_torch_available, is_torch_fx_proxy
#      32 if is_tf_available():
# ---> 33     import tensorflow as tf
#      35 if is_flax_available():
#      36     import jax.numpy as jnp
#
# File ~\anaconda3\lib\site-packages\tensorflow\__init__.py:45, in <module>
#      42 from tensorflow.python import tf2 as _tf2
#      43 _tf2.enable()
# ---> 45 from tensorflow._api.v2 import __internal__
#      46 from tensorflow._api.v2 import __operators__
#      47 from tensorflow._api.v2 import audio
#
# File ~\anaconda3\lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:11, in <module>
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
# ---> 11 from tensorflow._api.v2.__internal__ import distribute
#      12 from tensorflow._api.v2.__internal__ import eager_context
#      13 from tensorflow._api.v2.__internal__ import feature_column
#
# File ~\anaconda3\lib\site-packages\tensorflow\_api\v2\__internal__\distribute\__init__.py:8, in <module>
#       3 """Public API for tf._api.v2.__internal__.distribute namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__.distribute import combinations
#       9 from tensorflow._api.v2.__internal__.distribute import interim
#      10 from tensorflow._api.v2.__internal__.distribute import multi_process_runner
#
# File ~\anaconda3\lib\site-packages\tensorflow\_api\v2\__internal__\distribute\combinations\__init__.py:8, in <module>
#       3 """Public API for tf._api.v2.__internal__.distribute.combinations namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.distribute.combinations import env # line: 456
#       9 from tensorflow.python.distribute.combinations import generate # line: 365
#      10 from tensorflow.python.distribute.combinations import in_main_process # line: 418
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\distribute\combinations.py:33, in <module>
#      29 import six
#      32 from tensorflow.python.client import session
# ---> 33 from tensorflow.python.distribute import collective_all_reduce_strategy
#      34 from tensorflow.python.distribute import distribute_lib
#      35 from tensorflow.python.distribute import multi_process_runner
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\distribute\collective_all_reduce_strategy.py:25, in <module>
#      23 from tensorflow.core.protobuf import tensorflow_server_pb2
#      24 from tensorflow.python.distribute import collective_util
# ---> 25 from tensorflow.python.distribute import cross_device_ops as cross_device_ops_lib
#      26 from tensorflow.python.distribute import cross_device_utils
#      27 from tensorflow.python.distribute import device_util
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\distribute\cross_device_ops.py:28, in <module>
#      26 from tensorflow.python.client import device_lib
#      27 from tensorflow.python.distribute import collective_util
# ---> 28 from tensorflow.python.distribute import cross_device_utils
#      29 from tensorflow.python.distribute import device_util
#      30 from tensorflow.python.distribute import distribute_utils
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\distribute\cross_device_utils.py:22, in <module>
#      19 from typing import Callable, List, Optional, Union
#      21 from tensorflow.python.distribute import collective_util
# ---> 22 from tensorflow.python.distribute import values as value_lib
#      23 from tensorflow.python.eager import backprop_util
#      24 from tensorflow.python.eager import context
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\distribute\values.py:23, in <module>
#      21 from tensorflow.core.protobuf import struct_pb2
#      22 from tensorflow.python.distribute import device_util
# ---> 23 from tensorflow.python.distribute import distribute_lib
#      24 from tensorflow.python.distribute import packed_distributed_variable as packed
#      25 from tensorflow.python.distribute import reduce_util
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:205, in <module>
#     203 from tensorflow.python.autograph.core import ag_ctx as autograph_ctx
#     204 from tensorflow.python.autograph.impl import api as autograph
# --> 205 from tensorflow.python.data.ops import dataset_ops
#     206 from tensorflow.python.distribute import collective_util
#     207 from tensorflow.python.distribute import device_util
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\data\__init__.py:21, in <module>
#      15 """`tf.data.Dataset` API for input pipelines.
#      16
#      17 See [Importing Data](https://tensorflow.org/guide/data) for an overview.
#      18 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\data\experimental\__init__.py:97, in <module>
#      15 """Experimental API for building input pipelines.
#      16
#      17 This module contains experimental `Dataset` sources and transformations that can
#    (...)
#      93 @@UNKNOWN_CARDINALITY
#      94 """
#      96 # pylint: disable=unused-import
# ---> 97 from tensorflow.python.data.experimental import service
#      98 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      99 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\data\experimental\service\__init__.py:419, in <module>
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """API for using the tf.data service.
#      16
#      17 This module contains:
#    (...)
#     416   job of ParameterServerStrategy).
#     417 """
# --> 419 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     420 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     421 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py:26, in <module>
#      24 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      25 from tensorflow.python.data.experimental.service import _pywrap_utils
# ---> 26 from tensorflow.python.data.ops import dataset_ops
#      27 from tensorflow.python.data.ops import options as options_lib
#      28 from tensorflow.python.data.ops import structured_function
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:34, in <module>
#      32 from tensorflow.python.data.ops import dataset_autograph
#      33 from tensorflow.python.data.ops import debug_mode
# ---> 34 from tensorflow.python.data.ops import iterator_ops
#      35 from tensorflow.python.data.ops import options as options_lib
#      36 from tensorflow.python.data.ops import structured_function
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:41, in <module>
#      39 from tensorflow.python.saved_model import nested_structure_coder
#      40 from tensorflow.python.trackable import base as trackable
# ---> 41 from tensorflow.python.training.saver import BaseSaverBuilder
#      42 from tensorflow.python.util import deprecation
#      43 from tensorflow.python.util.compat import collections_abc
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\training\saver.py:50, in <module>
#      48 from tensorflow.python.saved_model.pywrap_saved_model import metrics
#      49 from tensorflow.python.trackable import base as trackable
# ---> 50 from tensorflow.python.training import py_checkpoint_reader
#      51 from tensorflow.python.training import training_util
#      52 from tensorflow.python.training.saving import saveable_object
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py:19, in <module>
#      17 from tensorflow.python.framework import errors_impl
#      18 from tensorflow.python.util import compat
# ---> 19 from tensorflow.python.util._pywrap_checkpoint_reader import CheckpointReader
#      20 from tensorflow.python.util.tf_export import tf_export
#      23 def error_translator(e):
#
# SystemError: initialization of _pywrap_checkpoint_reader raised unreported exception
